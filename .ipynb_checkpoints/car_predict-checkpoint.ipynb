# %% [markdown]
# ## Include libraries

# %%
import numpy as np                # For numerical operations
import pandas as pd               # For data manipulation
import matplotlib.pyplot as plt   # For visualization
import seaborn as sns             # For enhanced visualizations
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split  # For data splitting
from sklearn.linear_model import LinearRegression      # Linear Regression model
from sklearn.metrics import mean_squared_error, r2_score  # For performance evaluation

# %% [markdown]
# ## Import the data to panda dataframe

# %%
car_data = pd.read_csv("car-data.csv")
car_data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
car_data = car_data.drop('name', axis = 1)

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           4340 non-null   int64
#  1   selling_price  4340 non-null   int64
#  2   km_driven      4340 non-null   int64
#  3   fuel           4340 non-null   object
#  4   seller_type    4340 non-null   object
#  5   transmission   4340 non-null   object
#  6   owner          4340 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 237.5+ KB

# %%
print(car_data["fuel"].value_counts())
print(car_data["seller_type"].value_counts())
print(car_data["transmission"].value_counts())
print(car_data["owner"].value_counts())
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %% [markdown]
# ### Encoding Categorical Data to Numerical Values
#
# #### **Fuel Data Encoding**
# - **Diesel** → `0`
# - **Petrol** → `1`
# - **CNG** → `2`
# - **LPG** → `3`
# - **Electric** → `4`
#
# ---
#
# #### **Seller Type Data Encoding**
# - **Individual** → `0`
# - **Dealer** → `1`
# - **Trustmark Dealer** → `2`
#
# ---
#
# #### **Transmission Data Encoding**
# - **Manual** → `0`
# - **Automatic** → `1`
#
# ---
#
# #### **Owner Data Encoding**
# - **First Owner** → `0`
# - **Second Owner** → `1`
# - **Third Owner** → `2`
# - **Fourth & Above Owner** → `3`
# - **Test Drive Car** → `4`

# %%
car_data.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2007          60000      70000  Petrol  Individual       Manual
# 1  2007         135000      50000  Petrol  Individual       Manual
# 2  2012         600000     100000  Diesel  Individual       Manual
# 3  2017         250000      46000  Petrol  Individual       Manual
# 4  2014         450000     141000  Diesel  Individual       Manual
#
#           owner
# 0   First Owner
# 1   First Owner
# 2   First Owner
# 3   First Owner
# 4  Second Owner

# %%
print(car_data["fuel"].value_counts())
print(car_data["seller_type"].value_counts())
print(car_data["transmission"].value_counts())
print(car_data["owner"].value_counts())
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %%
car_data = pd.get_dummies(car_data, columns=["fuel", "seller_type", "transmission", "owner"])

# %%
car_data.tail()
# Out:
#       year  selling_price  km_driven  fuel_0  fuel_1  fuel_2  fuel_3  fuel_4  \
# 4335  2014         409999      80000    True   False   False   False   False
# 4336  2014         409999      80000    True   False   False   False   False
# 4337  2009         110000      83000   False    True   False   False   False
# 4338  2016         865000      90000    True   False   False   False   False
# 4339  2016         225000      40000   False    True   False   False   False
#
#       seller_type_0  seller_type_1  seller_type_2  transmission_0  \
# 4335           True          False          False            True
# 4336           True          False          False            True
# 4337           True          False          False            True
# 4338           True          False          False            True
# 4339           True          False          False            True
#
#       transmission_1  owner_0  owner_1  owner_2  owner_3  owner_4
# ...

# %%
sns.pairplot(car_data[['year', 'selling_price', 'km_driven']])
plt.show()

# %%
plt.figure(figsize=(16, 5))
sns.histplot(car_data['selling_price'], kde=True, bins=30)

plt.gca().get_xaxis().set_major_formatter(plt.FuncFormatter(lambda x, _: f'${x*1e-3:.0f}K'))

plt.title('Distribution of Car Prices')
plt.xlabel('Price')
plt.ylabel('Number of cars')
plt.show()

# %% [markdown]
# ### **Observation:**
#
# The histogram of car prices shows a **left-skewed distribution**, where the majority of the cars in the dataset are priced on the lower end. The higher frequency of cars in the lower price range indicates that most cars are **affordable or budget-friendly**. Conversely, there are fewer cars available in the **higher price range**, suggesting that luxury or high-end cars are less common in the dataset.

# %% [markdown]
# # Splitting the data for training and test

# %%
X = car_data.drop("selling_price", axis = 1)
Y = car_data["selling_price"]
print(X)
print(Y)
# Out:
#       year  km_driven  fuel_0  fuel_1  fuel_2  fuel_3  fuel_4  seller_type_0  \
# 0     2007      70000   False    True   False   False   False           True
# 1     2007      50000   False    True   False   False   False           True
# 2     2012     100000    True   False   False   False   False           True
# 3     2017      46000   False    True   False   False   False           True
# 4     2014     141000    True   False   False   False   False           True
# ...    ...        ...     ...     ...     ...     ...     ...            ...
# 4335  2014      80000    True   False   False   False   False           True
# 4336  2014      80000    True   False   False   False   False           True
# 4337  2009      83000   False    True   False   False   False           True
# 4338  2016      90000    True   False   False   False   False           True
# 4339  2016      40000   False    True   False   False   False           True
#
# ...

# %%
# Split the data into training set and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
# print(X_train)
# print(Y_train)
# # Initialize the StandardScaler
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# X_train_scaled = pd.DataFrame(X_train_scaled)
# X_test_scaled = pd.DataFrame(X_test_scaled)

# %% [markdown]
# # Train the Model

# %%
model = LinearRegression()
model.fit(X_train_scaled, Y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the scaled test data
Y_test_pred = model.predict(X_test_scaled)

# %% [markdown]
# ## Evaluate the model

# %%
# Calculate the Mean Squared Error (MSE) and R-squared
mse = mean_squared_error(Y_test, Y_test_pred)
r2 = r2_score(Y_test, Y_test_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 182146878750.28088
# R-squared: 0.403130360143212

# %%
# Create a scatter plot to compare actual vs predicted values
plt.figure(figsize=(8, 6))
plt.scatter(Y_test, Y_test_pred, color='blue', alpha=0.6)

# Adding labels and title
plt.title('Actual vs Predicted Values')
plt.xlabel('Actual Car Prices (Y_test)')
plt.ylabel('Predicted Car Prices (Y_test_prediction)')

# Show a line where actual = predicted for reference
plt.plot([min(Y_test), max(Y_test)], [min(Y_test), max(Y_test)], color='red', linestyle='--')

# Show the plot
plt.show()
